# %%
ds=[
["SRR5461431","NHF1_CPD_0h_10J_A"],
["SRR5461432","NHF1_CPD_0h_10J_B"],
["SRR5461433","NHF1_CPD_1h_10J_A"],
["SRR5461434","NHF1_CPD_1h_10J_B"],
["SRR5461435","NHF1_CPD_8h_10J_A"],
["SRR5461436","NHF1_CPD_8h_10J_B"],
["SRR5461437","NHF1_CPD_24h_10J_A"],
["SRR5461438","NHF1_CPD_24h_10J_B"],
["SRR5461439","NHF1_CPD_36h_10J_A"],
["SRR5461440","NHF1_CPD_36h_10J_B"],
["SRR5461441","NHF1_CPD_48h_10J_A"],
["SRR5461442","NHF1_CPD_48h_10J_B"],
["SRR5461445","NHF1_6-4PP_0h_20J_A"],
["SRR5461446","NHF1_6-4PP_0h_20J_B"],
["SRR5461447","NHF1_6-4PP_20min_20J_A"],
["SRR5461448","NHF1_6-4PP_20min_20J_B"],
["SRR5461449","NHF1_6-4PP_1h_20J_A"],
["SRR5461450","NHF1_6-4PP_1h_20J_B"],
["SRR5461451","NHF1_6-4PP_2h_20J_A"],
["SRR5461452","NHF1_6-4PP_2h_20J_B"],
["SRR5461453","NHF1_6-4PP_4h_20J_A"],
["SRR5461454","NHF1_6-4PP_4h_20J_B"],
]

xr=[
["SRR3062593","NHF1_CPD_1h_A"],
["SRR3062594","NHF1_CPD_1h_A"],
["SRR3062595","NHF1_CPD_1h_A"],
["SRR3062596","NHF1_CPD_1h_B"],
["SRR3062597","NHF1_CPD_1h_B"],
["SRR3062598","NHF1_CPD_1h_B"],
["SRR3062599","NHF1_CPD_4h_A"],
["SRR3062600","NHF1_CPD_4h_A"],
["SRR3062601","NHF1_CPD_4h_A"],
["SRR3062602","NHF1_CPD_4h_B"],
["SRR3062603","NHF1_CPD_4h_B"],
["SRR3062604","NHF1_CPD_4h_B"],
["SRR3062605","NHF1_CPD_8h_A"],
["SRR3062606","NHF1_CPD_8h_A"],
["SRR3062607","NHF1_CPD_8h_A"],
["SRR3062608","NHF1_CPD_8h_B"],
["SRR3062609","NHF1_CPD_8h_B"],
["SRR3062610","NHF1_CPD_8h_B"],
["SRR3062611","NHF1_CPD_16h_A"],
["SRR3062612","NHF1_CPD_16h_A"],
["SRR3062613","NHF1_CPD_16h_B"],
["SRR3062614","NHF1_CPD_16h_B"],
["SRR3062615","NHF1_CPD_24h_A"],
["SRR3062616","NHF1_CPD_24h_A"],
["SRR3062617","NHF1_CPD_24h_A"],
["SRR3062618","NHF1_CPD_24h_B"],
["SRR3062619","NHF1_CPD_24h_B"],
["SRR3062620","NHF1_CPD_24h_B"],
["SRR3062621","NHF1_CPD_48h_A"],
["SRR3062622","NHF1_CPD_48h_A"],
["SRR3062623","NHF1_CPD_48h_A"],
["SRR3062624","NHF1_CPD_48h_B"],
["SRR3062625","NHF1_CPD_48h_B"],
["SRR3062626","NHF1_CPD_48h_B"],
["SRR3062627","NHF1_6-4PP_5min_A"],
["SRR3062628","NHF1_6-4PP_5min_A"],
["SRR3062629","NHF1_6-4PP_5min_A"],
["SRR3062630","NHF1_6-4PP_5min_B"],
["SRR3062631","NHF1_6-4PP_5min_B"],
["SRR3062632","NHF1_6-4PP_5min_B"],
["SRR3062633","NHF1_6-4PP_20min_A"],
["SRR3062634","NHF1_6-4PP_20min_A"],
["SRR3062635","NHF1_6-4PP_20min_B"],
["SRR3062636","NHF1_6-4PP_20min_B"],
["SRR3062637","NHF1_6-4PP_1h_A"],
["SRR3062638","NHF1_6-4PP_1h_A"],
["SRR3062639","NHF1_6-4PP_1h_B"],
["SRR3062640","NHF1_6-4PP_1h_B"],
["SRR3062641","NHF1_6-4PP_2h_A"],
["SRR3062642","NHF1_6-4PP_2h_A"],
["SRR3062643","NHF1_6-4PP_2h_B"],
["SRR3062644","NHF1_6-4PP_2h_B"],
["SRR3062645","NHF1_6-4PP_4h_A"],
["SRR3062646","NHF1_6-4PP_4h_A"],
["SRR3062647","NHF1_6-4PP_4h_B"],
["SRR3062648","NHF1_6-4PP_4h_B"],
["SRR3062649","CS-B_6-4PP_5min_A"],
["SRR3062650","CS-B_6-4PP_5min_A"],
["SRR3062651","CS-B_6-4PP_5min_A"],
["SRR3062652","CS-B_6-4PP_5min_B"],
["SRR3062653","CS-B_6-4PP_5min_B"],
["SRR3062654","CS-B_6-4PP_5min_B"],
["SRR3062655","CS-B_6-4PP_1h_A"],
["SRR3062656","CS-B_6-4PP_1h_B"],
["SRR3062657","CS-B_6-4PP_2h_A"],
["SRR3062658","CS-B_6-4PP_2h_A"],
["SRR3062659","CS-B_6-4PP_2h_B"],
["SRR3062660","CS-B_6-4PP_2h_B"],
["SRR3062661","CS-B_6-4PP_4h_A"],
["SRR3062662","CS-B_6-4PP_4h_A"],
["SRR3062663","CS-B_6-4PP_4h_B"],
["SRR3062664","CS-B_6-4PP_4h_B"],
]

# %%
xr_dict={}
for data in xr:
    if data[1] not in xr_dict:
        xr_dict[data[1]]={"srr_id":data[0],"method":"XR","layout":"single","product":data[1].split("_")[1],"simulation":{"enabled":False}}
    else:
        xr_dict[data[1]]["srr_id"] += ":" + data[0]

ds_dict={}
for data in ds:
    if data[1] not in ds_dict:
        ds_dict[data[1]]={"srr_id":data[0],"method":"DS","layout":"single","product":data[1].split("_")[1],"simulation":{"enabled":False}}
    else:
        ds_dict[data[1]]["srr_id"] += ":" + data[0]

# %%
import yaml

with open("ds.yaml", "w") as f:
    yaml.dump(ds_dict, f, allow_unicode=True, default_flow_style=False)
